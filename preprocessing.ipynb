# %% [markdown]
# ---
# # **Crime data Exploratory Data Analysis: Pre-processing**
# ---

# %% [markdown]
# **1. Import Libraries**

# %%
import pandas as pd
import numpy as np
import glob # to import multiple files at once

# %% [markdown]
# **2. Load and Explore the Data**

# %% [markdown]
# City of London

# %%
# import all the city of london data in one dataframe

city_files = sorted(glob.glob("data/*/*city-of-london-street.csv")) # glob.glob returns a list of file paths matching the pattern, sorted to maintain order
city = pd.concat([pd.read_csv(file) for file in city_files], ignore_index=True) # ignore_index to reset the index after concatenation

# %%
city.info() # check the info of the dataframe to understand the data types and null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19577 entries, 0 to 19576
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Crime ID               19042 non-null  object
#  1   Month                  19577 non-null  object
#  2   Reported by            19577 non-null  object
#  3   Falls within           19577 non-null  object
#  4   Longitude              17937 non-null  float64
#  5   Latitude               17937 non-null  float64
#  6   Location               19577 non-null  object
#  7   LSOA code              17937 non-null  object
#  8   LSOA name              17937 non-null  object
#  9   Crime type             19577 non-null  object
#  10  Last outcome category  19042 non-null  object
#  11  Context                0 non-null      float64
# dtypes: float64(3), object(9)
# memory usage: 1.8+ MB

# %%
display(city.isnull().sum(), round(city.isnull().mean(), 2)) # check the number of null values in each column and the percentage of null values in each column
# Out:
# Crime ID                   535
# Month                        0
# Reported by                  0
# Falls within                 0
# Longitude                 1640
# Latitude                  1640
# Location                     0
# LSOA code                 1640
# LSOA name                 1640
# Crime type                   0
# Last outcome category      535
# Context                  19577
# dtype: int64
# Crime ID                 0.03
# Month                    0.00
# Reported by              0.00
# Falls within             0.00
# Longitude                0.08
# Latitude                 0.08
# Location                 0.00
# LSOA code                0.08
# LSOA name                0.08
# Crime type               0.00
# Last outcome category    0.03
# Context                  1.00
# dtype: float64

# %%
# remove context column as they have no values
city = city.drop(columns=["Context"], inplace=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 2
#       1 # removing context column as they have no values
# ----> 2 city = city.drop(columns=["Context"], inplace=False)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['Context'] not found in axis"

# %%
city.columns # check if the column has been removed
# Out:
# Index(['Crime ID', 'Month', 'Reported by', 'Falls within', 'Longitude',
#        'Latitude', 'Location', 'LSOA code', 'LSOA name', 'Crime type',
#        'Last outcome category'],
#       dtype='object')

# %%
# drop rows with null values in lsoa name column (location data)
city = city.dropna(subset=["LSOA name"], inplace=False)
city.isnull().sum()
# Out:
# Crime ID                 457
# Month                      0
# Reported by                0
# Falls within               0
# Longitude                  0
# Latitude                   0
# Location                   0
# LSOA code                  0
# LSOA name                  0
# Crime type                 0
# Last outcome category    457
# dtype: int64

# %%
# drop rows with null crime id and last outcome category

city = city.dropna(subset=["Crime ID", "Last outcome category"], inplace=False)
city.isnull().sum()
# Out:
# Crime ID                 0
# Month                    0
# Reported by              0
# Falls within             0
# Longitude                0
# Latitude                 0
# Location                 0
# LSOA code                0
# LSOA name                0
# Crime type               0
# Last outcome category    0
# dtype: int64

# %%
# Adding all the city of london data in one dataframe

city1 = pd.read_csv("data/2024-01/2024-01-city-of-london-street.csv")
city1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 734 entries, 0 to 733
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Crime ID               722 non-null    object
#  1   Month                  734 non-null    object
#  2   Reported by            734 non-null    object
#  3   Falls within           734 non-null    object
#  4   Longitude              657 non-null    float64
#  5   Latitude               657 non-null    float64
#  6   Location               734 non-null    object
#  7   LSOA code              657 non-null    object
#  8   LSOA name              657 non-null    object
#  9   Crime type             734 non-null    object
#  10  Last outcome category  722 non-null    object
#  11  Context                0 non-null      float64
# dtypes: float64(3), object(9)
# memory usage: 68.9+ KB

# %%
city = pd.read_csv("data/2024-01/2024-01-city-of-london-street.csv")
metro = pd.read_csv("data/2024-01/2024-01-metropolitan-street.csv")
surrey = pd.read_csv("data/2024-01/2024-01-surrey-street.csv")
thames = pd.read_csv("data/2024-01/2024-01-thames-valley-street.csv")
wmids = pd.read_csv("data/2024-01/2024-01-west-midlands-street.csv")
wyork = pd.read_csv("data/2024-01/2024-01-west-yorkshire-street.csv")

# %%
city.head()
# Out:
#                                             Crime ID    Month  \
# 0  e7b720d0e1302d2d06db7b28b29132eb194864d44d7921...  2024-01
# 1  e60a5ac62a80e866453254474137c3206417422c62f0c0...  2024-01
# 2  986f618142ec52b7f254e4b0549da2f17ceeb0e130db6c...  2024-01
# 3  05dc27a88748356f6d59b0bd1389710ebfb42b37e565af...  2024-01
# 4  373d78e2ccec5d05a547cd4bee19045a9e050042a0e6e7...  2024-01
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  City of London Police  City of London Police  -0.106220  51.518275
# 1  City of London Police  City of London Police  -0.107682  51.517786
# 2  City of London Police  City of London Police  -0.111596  51.518281
# 3  City of London Police  City of London Police  -0.111596  51.518281
# 4  City of London Police  City of London Police  -0.112096  51.515942
#
#                    Location  LSOA code    LSOA name             Crime type  \
# 0           On or near B500  E01000916  Camden 027B  Theft from the person
# 1           On or near B521  E01000917  Camden 027C            Other theft
# 2  On or near Chancery Lane  E01000914  Camden 028B            Other theft
# 3  On or near Chancery Lane  E01000914  Camden 028B  Theft from the person
# 4      On or near Nightclub  E01000914  Camden 028B  Theft from the person
#
#                            Last outcome category  Context
# 0  Investigation complete; no suspect identified      NaN
# 1  Investigation complete; no suspect identified      NaN
# 2  Investigation complete; no suspect identified      NaN
# 3                      Status update unavailable      NaN
# 4  Investigation complete; no suspect identified      NaN

# %%
metro.head()
# Out:
#                                             Crime ID    Month  \
# 0  e5b3ed0375b796067eb668f37a18094cce300bdbd5446c...  2024-01
# 1  d5d46efe4a74b2fdf87f28f7c89c4d7534c80d4150f58f...  2024-01
# 2  8ee491f5ebeda54bda879fed602d2f308bfd8abf4b59f7...  2024-01
# 3  318e91d9bd9ad081bb348b8c743236365c9178eb60229d...  2024-01
# 4  8ec949bf76f02215ad73b489ff502ab32101b0834b49fc...  2024-01
#
#                    Reported by                 Falls within  Longitude  \
# 0  Metropolitan Police Service  Metropolitan Police Service  -0.552328
# 1  Metropolitan Police Service  Metropolitan Police Service  -0.666558
# 2  Metropolitan Police Service  Metropolitan Police Service  -0.657460
# 3  Metropolitan Police Service  Metropolitan Police Service   0.876815
# 4  Metropolitan Police Service  Metropolitan Police Service   0.884060
#
#     Latitude                     Location  LSOA code     LSOA name  \
# 0  50.853155      On or near Queen Street  E01031392     Arun 001C
# 1  50.848940  On or near Northfields Lane  E01031396     Arun 003D
# 2  50.787270         On or near Kingsmead  E01031419     Arun 015C
# 3  51.147655      On or near Parking Area  E01034986  Ashford 005G
# 4  51.110654   On or near Southdown Close  E01034989  Ashford 010G
#
#                      Crime type        Last outcome category  Context
# 0                   Other theft  Unable to prosecute suspect      NaN
# 1  Violence and sexual offences    Status update unavailable      NaN
# 2  Violence and sexual offences    Status update unavailable      NaN
# 3  Violence and sexual offences    Status update unavailable      NaN
# 4  Violence and sexual offences    Status update unavailable      NaN

# %%
surrey.head()
# Out:
#                                             Crime ID    Month    Reported by  \
# 0  a21e838add64c3345496907f148dd922f876219f984d29...  2024-01  Surrey Police
# 1  6f797cbcab36f245e49e9e69da33e8818669fd81f7df27...  2024-01  Surrey Police
# 2  fc789288d77042ae6d8082da50db413b68d04610b2ca1d...  2024-01  Surrey Police
# 3  4d2ced487c3343612394d241bab83e894a8c7e1255e4a7...  2024-01  Surrey Police
# 4  7d7b66030d69eae7f5c4b544e7f9808ec0679dd7eaa956...  2024-01  Surrey Police
#
#     Falls within  Longitude  Latitude               Location  LSOA code  \
# 0  Surrey Police  -0.101292  51.51477  On or near Amen Court  E01032739
# 1  Surrey Police  -0.101292  51.51477  On or near Amen Court  E01032739
# 2  Surrey Police  -0.101292  51.51477  On or near Amen Court  E01032739
# 3  Surrey Police  -0.101292  51.51477  On or near Amen Court  E01032739
# 4  Surrey Police  -0.101292  51.51477  On or near Amen Court  E01032739
#
#              LSOA name                    Crime type  \
# 0  City of London 001F  Violence and sexual offences
# 1  City of London 001F                   Other theft
# 2  City of London 001F                   Other theft
# 3  City of London 001F                   Other theft
# 4  City of London 001F                 Vehicle crime
#
#                            Last outcome category  Context
# 0                    Unable to prosecute suspect      NaN
# 1                    Unable to prosecute suspect      NaN
# 2  Investigation complete; no suspect identified      NaN
# 3  Investigation complete; no suspect identified      NaN
# 4  Investigation complete; no suspect identified      NaN
